# %%
from optim import optim
from run_option.option import Options

# %%
opts = Options().get_args()

# %%
text='a person with purple hair'
input_img='input_img/img1.png'
region={'organ': ['hair']}

# %%
result = optim(text=text, input_img=input_img, opts=opts,region=region)

# %%
from torchvision.utils import make_grid
from torchvision.transforms import ToPILImage
result_image = ToPILImage()(make_grid(result.detach().cpu(), normalize=True, scale_each=True, range=(-1, 1), padding=0))
h, w = result_image.size
result_image.resize((h // 2, w // 2))

# %%
text='a person with purple hair'
input_img='input_img/img1.png'
region={'organ': ['hair']}

# %%
result = optim(text=text, input_img=input_img, opts=opts,region=region)
# Out:
# Loading ResNet ArcFace
# loss: 0.7871;:   0%|          | 0/30 [00:00<?, ?it/s]/home/wangyuchi/anaconda3/envs/makeup/lib/python3.6/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# loss: 0.7666;: 100%|██████████| 30/30 [00:06<00:00,  4.96it/s]

# %%
from torchvision.utils import make_grid
from torchvision.transforms import ToPILImage
result_image = ToPILImage()(make_grid(result.detach().cpu(), normalize=True, scale_each=True, range=(-1, 1), padding=0))
h, w = result_image.size
result_image.resize((h // 2, w // 2))
# Out:
# <PIL.Image.Image image mode=RGB size=2048x512 at 0x7F34244B4240>
